# %% [markdown]
# <h1>Coursere Capstone Project<h1>

# %% [markdown]
# <h3>Introduction<h3>

# %% [markdown]
# <p>Jeronimo wants to open his Burger Joint in some Locality (District) of Bogotá, Colombia, and he is asking our help in finding the best Locality.<p>

# %% [markdown]
# <h3>Business Problem<h3>

# %% [markdown]
# <p>In order to open Jeronimo's burger joint, we will have the need to use some information about the Localities in Bogotá We must be sure that the place where the burger joint is opened will have enough customers and also that there aren't a large ammount of burer joints in the place.
# <p>
